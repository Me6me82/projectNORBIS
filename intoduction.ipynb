# %%
a = 1
a + 1
# Out:
# 2

# %%
a = 5

# %%
b = 4

# %%
print a
# Out:
# 5

# %%
print b
# Out:
# 4

# %%
# %whos
# Out:
# Variable   Type    Data/Info
# ----------------------------
# a          int     5
# b          int     4

# %%
# %ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 38A6-2D2B
#
#  Directory of C:\Users\Mohamed Abdelhalim\NORBIS_notbook_day2
#
# 07/08/2018  14:39    <DIR>          .
# 07/08/2018  14:39    <DIR>          ..
# 07/08/2018  14:09    <DIR>          .ipynb_checkpoints
# 07/08/2018  14:39           866,570 Untitled.ipynb
#                1 File(s)        866,570 bytes
#                3 Dir(s)  308,838,092,800 bytes free

# %% [markdown]
# ![how to add image](attachment:image.png)

# %% [markdown]
# # top heading

# %%
# %%timeit 
      range(1000)
      range(2000)
# Out:
# 10000 loops, best of 3: 23.8 µs per loop
